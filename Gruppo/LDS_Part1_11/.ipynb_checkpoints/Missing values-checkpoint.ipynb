# %% [markdown]
# # Gestione dei missing values

# %%
import pandas as pd
import numpy as np

# %%
match = pd.read_csv('output/match.csv')
tournament = pd.read_csv('output/tournament.csv')
player = pd.read_csv('output/players.csv')

match_originale = match.copy()
tournament_originale = tournament.copy()
player_originale = player.copy()

# %%
#check
tennis = pd.read_csv('dati/tennis.csv')
male = pd.read_csv('dati/male_players.csv')
female = pd.read_csv('dati/female_players.csv')
male['Name'] = male['name'] + ' ' + male['surname']
female['Name'] = female['name'] + ' ' + female['surname']
# Out:
# C:\Users\Francesco\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
names = {}

# %%
for index, row in tennis.iterrows():
    if male.Name.isin([row['winner_name']]):
        names.append(row['winnner_name'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-bee86a573fcc> in <module>
#       1 for index, row in tennis.iterrows():
# ----> 2     if male.Name.isin([row['winner_name']]):
#       3         names.append(row['winnner_name'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
match.isna().sum()
# Out:
# tourney_date               0
# match_num                  0
# winner_id                  0
# loser_id                   0
# score                    169
# best_of                    0
# round                      0
# minutes               104430
# w_ace                 103782
# w_df                  103782
# w_svpt                103782
# w_1stIn               103782
# w_1stWon              103782
# w_2ndWon              103782
# w_SvGms               103778
# w_bpSaved             103782
# w_bpFaced             103782
# l_ace                 103782
# l_df                  103782
# l_svpt                103782
# l_1stIn               103782
# l_1stWon              103782
# l_2ndWon              103782
# l_SvGms               103778
# l_bpSaved             103782
# l_bpFaced             103782
# winner_rank            19372
# winner_rank_points     19388
# loser_rank             35232
# loser_rank_points      35248
# tourney_pk                 0
# dtype: int64

# %%
player[player.year_of_birth == -1]
# Out:
#        player_id country_id                   name     sex hand  ht  \
# 1         223675        EGY   Farah Haitham Kassem  female    U NaN
# 3         223157        RUS          Valeria Monko  female    U NaN
# 8         221965        BEL  Morgane Van Den Bergh  female    R NaN
# 11        222423        GER            Pia Schwarz  female    R NaN
# 18        222697        EGY        Dareen Elleithy  female    U NaN
# ...          ...        ...                    ...     ...  ...  ..
# 10046     239429        INA      Fitriani Sabatini  female    U NaN
# 10048     223034        ITA        Grazia Fabbrizi  female    U NaN
# 10049     222699        EGY           Hana El Deeb  female    R NaN
# 10057     222740        UKR         Mariia Hurieva  female    R NaN
# 10065     235160        SVK         Salma Drugdova  female    U NaN
#
#        year_of_birth
# 1                 -1
# 3                 -1
# 8                 -1
# 11                -1
# 18                -1
# ...              ...
# 10046             -1
# 10048             -1
# 10049             -1
# 10057             -1
# 10065             -1
#
# [2108 rows x 7 columns]

# %%
match[match.winner_id == '239429']
# Out:
# Empty DataFrame
# Columns: [tourney_date, match_num, winner_id, loser_id, score, best_of, round, minutes, w_ace, w_df, w_svpt, w_1stIn, w_1stWon, w_2ndWon, w_SvGms, w_bpSaved, w_bpFaced, l_ace, l_df, l_svpt, l_1stIn, l_1stWon, l_2ndWon, l_SvGms, l_bpSaved, l_bpFaced, winner_rank, winner_rank_points, loser_rank, loser_rank_points, tourney_pk]
# Index: []
#
# [0 rows x 31 columns]

# %%
match
# Out:
#         tourney_date  match_num  winner_id  loser_id         score  best_of  \
# 0           20191111          5     214229    210421       7-5 6-2        3
# 1           20180326         15     213853    215750   6-3 4-6 6-0        3
# 2           20200928        148     104919    105166       7-5 6-0        3
# 3           20161010        279     104542    104386    6-3 7-6(6)        3
# 4           20201214        211     213976    221380  6-3 5-7 10-7        3
# ...              ...        ...        ...       ...           ...      ...
# 185759      20181203         19     203288    211668       6-1 6-1        3
# 185760      20200217        114     220489    220613   6-2 4-6 6-2        3
# 185761      20180716        272     105302    126504       6-3 6-4        3
# 185762      20170605        299     111442    104460       6-3 7-5        3
# 185763      20210517        206     215926    220943  6-1 4-6 11-9        3
#
#        round  minutes  w_ace  w_df  ...  l_1stWon  l_2ndWon  l_SvGms  \
# 0         Q1      NaN    NaN   NaN  ...       NaN       NaN      NaN
# 1        R32      NaN    NaN   NaN  ...       NaN       NaN      NaN
# 2         Q1     86.0    3.0   6.0  ...      21.0       9.0      9.0
# 3        R32    100.0    5.0   3.0  ...      34.0      12.0     10.0
# 4         Q2      NaN    NaN   NaN  ...       NaN       NaN      NaN
# ...      ...      ...    ...   ...  ...       ...       ...      ...
# 185759   R16      NaN    NaN   NaN  ...       NaN       NaN      NaN
# 185760   R32      NaN    NaN   NaN  ...       NaN       NaN      NaN
# 185761   R32     81.0    8.0   1.0  ...      24.0       9.0      9.0
# 185762    SF     66.0    4.0   1.0  ...      25.0      13.0     10.0
# 185763    Q2      NaN    NaN   NaN  ...       NaN       NaN      NaN
#
#         l_bpSaved  l_bpFaced  winner_rank  winner_rank_points  loser_rank  \
# 0             NaN        NaN        755.0                28.0         NaN
# 1             NaN        NaN        668.0                32.0       746.0
# 2             4.0        9.0        123.0               482.0       205.0
# 3             6.0        8.0         13.0              2625.0       158.0
# 4             NaN        NaN       1056.0                12.0         NaN
# ...           ...        ...          ...                 ...         ...
# 185759        NaN        NaN        227.0               263.0       634.0
# 185760        NaN        NaN        717.0                34.0       762.0
# 185761        2.0        5.0        260.0               210.0       331.0
# 185762        2.0        4.0         92.0               592.0        76.0
# 185763        NaN        NaN       1274.0                 6.0         NaN
#
#         loser_rank_points                                       tourney_pk
# 0                     NaN    2019-W-ITF-THA-12A-201925201941111W25 Hua Hin
# 1                    23.0  2018-W-WITF-TUR-12A-201815201810326Antalya $15K
# 2                   270.0                  2020-520G202030928Roland Garros
# 3                   378.0              2016-5014M201641010Shanghai Masters
# 4                     NaN    2020-W-ITF-TUR-25A-202015202041214W15 Antalya
# ...                   ...                                              ...
# 185759               37.0  2018-W-WITF-IND-04A-201825201841203Solapur $25K
# 185760               27.0   2020-W-ITF-TUN-07A-202015202010217W15 Monastir
# 185761              141.0   2018-3945C201830716San Benedetto Del Tronto CH
# 185762              685.0                   2017-7297C201720605Surbiton CH
# 185763                NaN    2021-W-ITF-TUR-20A-202115202120517W15 Antalya
#
# [185764 rows x 31 columns]

# %%
match.describe()
# Out:
#            match_num      winner_id       loser_id        best_of  \
# count  185764.000000  185764.000000  185764.000000  185764.000000
# mean      160.464175  180105.888068  181613.891987       3.034162
# std       289.562750   46571.821798   46645.664816       0.259146
# min         1.000000  100644.000000  100644.000000       3.000000
# 25%        17.000000  122330.000000  124079.000000       3.000000
# 50%       130.000000  203526.000000  205815.000000       3.000000
# 75%       272.000000  214152.000000  214818.000000       3.000000
# max      8312.000000  245099.000000  245099.000000       5.000000
#
#             minutes         w_ace          w_df        w_svpt       w_1stIn  \
# count  81334.000000  81982.000000  81982.000000  81982.000000  81982.000000
# mean      97.695269      4.823388      2.855907     71.297004     44.270901
# std       41.516997      4.389558      2.420502     25.530921     16.950740
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       72.000000      2.000000      1.000000     53.000000     33.000000
# 50%       91.000000      4.000000      2.000000     67.000000     42.000000
# 75%      119.000000      7.000000      4.000000     87.000000     54.000000
# max     4756.000000     75.000000    114.000000   1957.000000   1330.000000
#
#            w_1stWon  ...       l_1stIn      l_1stWon      l_2ndWon  \
# count  81982.000000  ...  81982.000000  81982.000000  81982.000000
# mean      32.142848  ...     44.565112     28.046169     12.715657
# std       11.414119  ...     16.777904     12.274711      6.322835
# min        0.000000  ...      0.000000      0.000000      0.000000
# 25%       24.000000  ...     33.000000     19.000000      8.000000
# 50%       30.000000  ...     42.000000     26.000000     12.000000
# 75%       38.000000  ...     54.000000     35.000000     16.000000
# max      836.000000  ...    893.000000    532.000000    399.000000
#
#             l_SvGms     l_bpSaved     l_bpFaced    winner_rank  \
# count  81986.000000  81982.000000  81982.000000  166392.000000
# mean      10.942612      4.658608      8.864238     383.957919
# std        3.499454      3.148033      3.967422     314.201072
# min        0.000000      0.000000      0.000000       1.000000
# 25%        9.000000      2.000000      6.000000     137.000000
# 50%       10.000000      4.000000      8.000000     298.000000
# 75%       13.000000      6.000000     11.000000     562.000000
# max       50.000000    120.000000    190.000000    2220.000000
#
#        winner_rank_points     loser_rank  loser_rank_points
# count       166376.000000  150532.000000      150516.000000
# mean           470.958107     434.321320         356.754518
# std           1041.945639     355.975553         703.270209
# min              1.000000       1.000000           1.000000
# 25%             49.000000     156.000000          35.000000
# 50%            161.000000     325.000000         138.000000
# 75%            439.000000     642.000000         378.000000
# max          16950.000000    2257.000000       16950.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# ## Eliminazione sottogruppo nullo

# %%
match = match.dropna(subset=['w_ace'])
match_originale = match_originale.dropna(subset=['w_ace']) #Aggiorno anche il riferimento ai dati originali vista la quantità

# %%
match.isna().sum()
# Out:
# match_num                0
# winner_id                0
# loser_id                 0
# score                    0
# best_of                  0
# round                    0
# minutes                801
# w_ace                    0
# w_df                     0
# w_svpt                   0
# w_1stIn                  0
# w_1stWon                 0
# w_2ndWon                 0
# w_SvGms                  0
# w_bpSaved                0
# w_bpFaced                0
# l_ace                    0
# l_df                     0
# l_svpt                   0
# l_1stIn                  0
# l_1stWon                 0
# l_2ndWon                 0
# l_SvGms                  0
# l_bpSaved                0
# l_bpFaced                0
# winner_rank            899
# winner_rank_points     913
# loser_rank            3123
# loser_rank_points     3138
# tourney_pk               0
# dtype: int64

# %% [markdown]
# ## Gestione dei rank

# %%
match['winner_rank'] = match.winner_rank.fillna(int(np.mean(match.winner_rank)))
match['winner_rank_points'] = match.winner_rank_points.fillna(int(np.mean(match.winner_rank_points)))
match['loser_rank'] = match.loser_rank.fillna(int(np.mean(match.loser_rank)))
match['loser_rank_points'] = match.loser_rank_points.fillna(int(np.mean(match.loser_rank_points)))

match['minutes'] = match.groupby('tourney_pk')['minutes'].apply(lambda x: x.ffill().bfill())
match = match.dropna(subset=['minutes'])

match = match.astype({"minutes": int, "w_ace": int, "w_df": int, "w_svpt": int,
                      "w_1stIn": int, "w_1stWon": int, "w_2ndWon": int, "w_SvGms": int,
                      "w_bpSaved": int, "w_bpFaced": int, "l_ace": int, "l_df": int,
                      "l_svpt": int, "l_1stIn": int, "l_1stWon": int, "l_2ndWon": int,
                      "l_SvGms": int, "l_bpSaved": int, "l_bpFaced": int
                    })

# %%
match['winner_rank'].hist(bins=20)
match_originale['winner_rank'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
match['winner_rank_points'].hist(bins=20)
match_originale['winner_rank_points'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
match['loser_rank_points'].hist(bins=20)
match_originale['loser_rank_points'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
match['loser_rank'].hist(bins=20)
match_originale['loser_rank'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Player - gestione hand e ht

# %%
player
# Out:
#        player_id country_id                  name     sex hand  ht  \
# 0         109336        MAR       Ayoub Chakrouni    male    U NaN
# 1         223675        EGY  Farah Haitham Kassem  female    U NaN
# 2         214169        FIN     Johanna Ranta Aho  female    U NaN
# 3         223157        RUS         Valeria Monko  female    U NaN
# 4         206030        GER       Julia Wachaczyk  female    L NaN
# ...          ...        ...                   ...     ...  ...  ..
# 10069     204265        CZE       Martina Borecka  female    R NaN
# 10070     220598        THA       Aunchisa Chanta  female    U NaN
# 10071     206227        TUR            Cemre Anil  female    R NaN
# 10072     206750        EST         Daniil Glinka    male    U NaN
# 10073     204304        MAS     Jawairiah Noordin  female    R NaN
#
#        year_of_birth
# 0               1991
# 1                 -1
# 2               1995
# 3                 -1
# 4               1994
# ...              ...
# 10069           1991
# 10070           2002
# 10071           1993
# 10072           2000
# 10073           1990
#
# [10074 rows x 7 columns]

# %%
player.loc[player.year_of_birth < 1, 'year_of_birth'] = None
player_originale.loc[player_originale.year_of_birth < 1, 'year_of_birth'] = None

player.isna().sum()
# Out:
# player_id           0
# country_id          0
# name                0
# sex                 0
# hand                0
# ht                  0
# year_of_birth    2108
# dtype: int64

# %%
player['hand'] = player.hand.fillna('U')
player_originale.loc[player_originale.ht < 100, 'ht'] = None
player.loc[player.ht < 100, 'ht'] = None
player['ht'] = player.groupby('sex')['ht'].apply(lambda x: x.ffill().bfill())

player = player.astype({"ht": int})

# %%
player['hand'].value_counts(dropna=False).plot(kind="bar")
player_originale['hand'].value_counts(dropna=False).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
player['ht'][player.sex == "male"].hist()
player_originale['ht'][player.sex == "male"].hist()
# Out:
# <AxesSubplot:>

# %%
player['ht'][player.sex != "male"].hist()
player_originale['ht'][player.sex != "male"].hist()
# Out:
# <AxesSubplot:>

# %%
player['year_of_birth'] = player.year_of_birth.ffill().bfill()


player['year_of_birth'].hist()
player_originale['year_of_birth'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Tournament - gestione surface

# %%
tournament
# Out:
#                                              tourney_pk  \
# 0     2018-W-WITF-THA-11A-201815201841029Nonthaburi ...
# 1     2017-W-WITF-USA-24A-201725201730731Fort Worth ...
# 2                           2017-0825I201730925Tashkent
# 3     2018-M-DC-2018-G2-AO-M-THA-LBN-01D201830915Dav...
# 4        2019-W-ITF-KOR-05A-201915201920610W15 Gimcheon
# ...                                                 ...
# 4906    2016-W-C100-UAE-01A-2016100201641212Dubai $100K
# 4907                         2019-2001C201941111Houston
# 4908     2018-W-WITF-FRA-17A-201825201830702Denain $25K
# 4909  2017-W-FC-2017-G1-AM-B-M-MEX-CHI-01D201710210F...
# 4910    2017-W-WITF-TUR-31A-201715201730911Antalya $15K
#
#                                tourney_id    date_id  \
# 0                2018-W-WITF-THA-11A-2018  201841029
# 1                2017-W-WITF-USA-24A-2017  201730731
# 2                               2017-0825  201730925
# 3       2018-M-DC-2018-G2-AO-M-THA-LBN-01  201830915
# 4                 2019-W-ITF-KOR-05A-2019  201920610
# ...                                   ...        ...
# 4906             2016-W-C100-UAE-01A-2016  201641212
# 4907                            2019-2001  201941111
# 4908             2018-W-WITF-FRA-17A-2018  201830702
# 4909  2017-W-FC-2017-G1-AM-B-M-MEX-CHI-01  201710210
# 4910             2017-W-WITF-TUR-31A-2017  201730911
#
#                      tourney_name surface  draw_size tourney_level  \
# 0                 Nonthaburi $15K    Hard         32            15
# 1              Fort Worth TX $25K    Hard         32            25
# 2                        Tashkent    Hard         32             I
# 3     Davis Cup G2 R3: THA vs LBN    Hard          4             D
# 4                    W15 Gimcheon    Hard         32            15
# ...                           ...     ...        ...           ...
# 4906                  Dubai $100K    Hard         32           100
# 4907                      Houston    Hard         64             C
# 4908                  Denain $25K    Clay         32            25
# 4909    Fed Cup G1 RR: MEX vs CHI    Hard          2             D
# 4910                 Antalya $15K    Clay         32            15
#
#       tourney_spectators  tourney_revenue
# 0                   3352        624465.14
# 1                   3179        737653.37
# 2                   3205        645386.98
# 3                    352         68449.92
# 4                   4484        995189.96
# ...                  ...              ...
# 4906                2515        551251.77
# 4907                5691       1046990.04
# 4908                3125        675189.06
# 4909                 189         37959.40
# 4910                3533        732126.20
#
# [4911 rows x 9 columns]

# %%
tournament.isna().sum()
# Out:
# tourney_pk             0
# tourney_id             0
# date_id                0
# tourney_name           0
# surface               62
# draw_size              0
# tourney_level          0
# tourney_spectators     0
# tourney_revenue        0
# dtype: int64

# %%
tournament['surface'] = tournament.groupby('tourney_name')['surface'].apply(lambda x: x.ffill().bfill())
tournament['surface'] = tournament.surface.fillna('Hard')

# %%
tournament_originale.surface.value_counts(dropna=False).plot(kind="bar")
tournament.surface.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
match.to_csv('output/match_noNull.csv', index=False)
player.to_csv('output/players_noNull.csv', index=False)
tournament.to_csv('output/tournament_noNull.csv', index=False)

# %%
match
# Out:
#         match_num  winner_id  loser_id        score  best_of round  minutes  \
# 0             256     116985    200389      6-2 6-2        3    Q1       58
# 2             274     111202    105029      6-0 6-2        3   R32       56
# 3             250     105815    144707   6-3 7-6(2)        3    Q1       92
# 5             256     126845    105731      6-3 6-3        3   R64       82
# 10            266     111576    105432      6-3 6-3        3    Q3       68
# ...           ...        ...       ...          ...      ...   ...      ...
# 185755        292     106137    105948   6-4 7-6(6)        3   R16      100
# 185758        299     105155    104259      6-3 7-5        3    SF       87
# 185760        293     126774    105819      6-3 6-4        3   R16       86
# 185761        287     111200    106210  6-2 3-6 6-4        3   R16      140
# 185763        243     105902    134329   7-6(0) 6-2        3    Q2       92
#
#         w_ace  w_df  w_svpt  ...  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  \
# 0           5     1      59  ...        21        15        8          6
# 2           1     2      34  ...        16         3        7          3
# 3           9     4      67  ...        26        11       10          5
# 5          12     2      56  ...        22        11        9          6
# 10          2     0      59  ...        27         7        9          2
# ...       ...   ...     ...  ...       ...       ...      ...        ...
# 185755      0     1      68  ...        38         9       11          6
# 185758      0     5      89  ...        21         8       10          2
# 185760      5     2      60  ...        28         6        9          6
# 185761      2     3      87  ...        38        18       13         11
# 185763      7     1      64  ...        25        18       10          7
#
#         l_bpFaced  winner_rank  winner_rank_points  loser_rank  \
# 0              10        559.0                60.0       271.0
# 2               8        145.0               401.0       518.0
# 3               8         48.0              1048.0        80.0
# 5               9        280.0               145.0       307.0
# 10              5        409.0               105.0       406.0
# ...           ...          ...                 ...         ...
# 185755         11        254.0               179.0       179.0
# 185758          6        124.0               443.0        80.0
# 185760          9         10.0              3030.0        97.0
# 185761         15        122.0               453.0        80.0
# 185763         11        418.0                93.0       440.0
#
#         loser_rank_points                        tourney_pk
# 0                   584.0     2016-1797C201620425Ostrava CH
# 2                    67.0    2016-7027C201630912Nanchang CH
# 3                   763.0        2020-0414A202030921Hamburg
# 5                   107.0  2019-7203C201910128Launceston CH
# 10                  107.0     2016-6156C201620627Marburg CH
# ...                   ...                               ...
# 185755              292.0       2019-6757C201920617Blois CH
# 185758              686.0    2019-9124C201930923Florence CH
# 185760              613.0        2019-7290A201920429Estoril
# 185761              720.0   2018-0558C201820604Prostejov CH
# 185763               86.0        2018-7316C201830910Cary CH
#
# [81919 rows x 30 columns]

# %%
match[['match_num','winner_id','tourney_pk']].drop_duplicates()
# Out:
#         match_num  winner_id                        tourney_pk
# 0             256     116985     2016-1797C201620425Ostrava CH
# 2             274     111202    2016-7027C201630912Nanchang CH
# 3             250     105815        2020-0414A202030921Hamburg
# 5             256     126845  2019-7203C201910128Launceston CH
# 10            266     111576     2016-6156C201620627Marburg CH
# ...           ...        ...                               ...
# 185755        292     106137       2019-6757C201920617Blois CH
# 185758        299     105155    2019-9124C201930923Florence CH
# 185760        293     126774        2019-7290A201920429Estoril
# 185761        287     111200   2018-0558C201820604Prostejov CH
# 185763        243     105902        2018-7316C201830910Cary CH
#
# [81918 rows x 3 columns]
