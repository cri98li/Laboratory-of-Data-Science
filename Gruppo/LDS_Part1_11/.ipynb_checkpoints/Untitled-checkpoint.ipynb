# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
tennis = pd.read_csv('dati/tennis.csv')
male = pd.read_csv('dati/male_players.csv')
female = pd.read_csv('dati/female_players.csv')
# Out:
# C:\Users\Francesco\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
test = pd.read_csv('output/match.csv')
test1 = pd.read_csv('output/tournament.csv')

# %%
test1
# Out:
#                                              tourney_pk  \
# 0     2017-W-WITF-FIN-02A-201715201730731Savitaipale...
# 1                      2021-0403M202110322Miami Masters
# 2                          2021-7791C202120607Almaty CH
# 3           2016-W-C10-AUT-03A-201610201630815Graz $10K
# 4     2017-W-FC-2017-G2-AO-B-M-HKG-IRI-01D201730720F...
# ...                                                 ...
# 4907    2017-W-WITF-THA-03A-201725201720508Hua Hin $25K
# 4908  2016-W-FC-2016-G1-EPA-A-M-SWE-UKR-01D201610205...
# 4909     2020-W-ITF-FRA-06A-202015202010309W15+H Amiens
# 4910    2016-W-C10-KAZ-04B-201610201630919Shymkent $10K
# 4911                      2017-M035I201730731Washington
#
#                                 tourney_id    date_id  \
# 0                 2017-W-WITF-FIN-02A-2017  201730731
# 1                                2021-0403  202110322
# 2                                2021-7791  202120607
# 3                  2016-W-C10-AUT-03A-2016  201630815
# ...

# %%
test1[['tourney_id','date_id','surface']].drop_duplicates()
test1[['tourney_pk']].drop_duplicates()
# Out:
#                                              tourney_pk
# 0     2017-W-WITF-FIN-02A-201715201730731Savitaipale...
# 1                      2021-0403M202110322Miami Masters
# 2                          2021-7791C202120607Almaty CH
# 3           2016-W-C10-AUT-03A-201610201630815Graz $10K
# 4     2017-W-FC-2017-G2-AO-B-M-HKG-IRI-01D201730720F...
# ...                                                 ...
# 4907    2017-W-WITF-THA-03A-201725201720508Hua Hin $25K
# 4908  2016-W-FC-2016-G1-EPA-A-M-SWE-UKR-01D201610205...
# 4909     2020-W-ITF-FRA-06A-202015202010309W15+H Amiens
# 4910    2016-W-C10-KAZ-04B-201610201630919Shymkent $10K
# 4911                      2017-M035I201730731Washington
#
# [4912 rows x 1 columns]

# %%
tennis
# Out:
#                      tourney_id    tourney_name surface  draw_size  \
# 0                     2019-M020        Brisbane    Hard         32
# 1                     2019-M020        Brisbane    Hard         32
# 2                     2019-M020        Brisbane    Hard         32
# 3                     2019-M020        Brisbane    Hard         32
# 4                     2019-M020        Brisbane    Hard         32
# ...                         ...             ...     ...        ...
# 186068  2020-W-ITF-USA-48A-2020  W25 Orlando FL    Hard         32
# 186069  2020-W-ITF-USA-48A-2020  W25 Orlando FL    Hard         32
# 186070  2020-W-ITF-USA-48A-2020  W25 Orlando FL    Hard         32
# 186071  2020-W-ITF-USA-48A-2020  W25 Orlando FL    Hard         32
# 186072  2020-W-ITF-USA-48A-2020  W25 Orlando FL    Hard         32
#
#        tourney_level  tourney_date  match_num  winner_id winner_entry  \
# 0                  A      20181231        300     105453          NaN
# ...

# %%
tennis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186073 entries, 0 to 186072
# Data columns (total 49 columns):
# tourney_id            186073 non-null object
# tourney_name          186073 non-null object
# surface               185911 non-null object
# draw_size             186073 non-null int64
# tourney_level         186073 non-null object
# tourney_date          186073 non-null int64
# match_num             186073 non-null int64
# winner_id             186073 non-null int64
# winner_entry          25822 non-null object
# winner_name           186073 non-null object
# winner_hand           186057 non-null object
# winner_ht             49328 non-null float64
# winner_ioc            186073 non-null object
# winner_age            183245 non-null float64
# loser_id              186073 non-null int64
# loser_entry           44146 non-null object
# loser_name            186073 non-null object
# loser_hand            186002 non-null object
# ...

# %%
id1 = np.unique(tennis.loser_id)
id2 = np.unique(tennis.winner_id)
len(id1) + len(id2)
# Out:
# 16207

# %%
tennis[(tennis.loser_age.isna()) | (tennis.winner_age.isna())]
# Out:
#                                tourney_id                 tourney_name  \
# 5883    2019-M-DC-2019-G2-AM-M-MEX-PAR-01  Davis Cup G2 R1: MEX vs PAR
# 5890    2019-M-DC-2019-G2-AO-M-NZL-INA-01  Davis Cup G2 R1: NZL vs INA
# 6808    2018-M-DC-2018-G2-AM-M-PUR-MEX-01  Davis Cup G2 R1: PUR vs MEX
# 6810    2018-M-DC-2018-G2-AM-M-PUR-MEX-01  Davis Cup G2 R1: PUR vs MEX
# 6811    2018-M-DC-2018-G2-AM-M-PUR-MEX-01  Davis Cup G2 R1: PUR vs MEX
# ...                                   ...                          ...
# 185940            2020-W-ITF-USA-42A-2020                 W80 Tyler TX
# 185999            2020-W-ITF-USA-47A-2020           W100 Charleston SC
# 186009            2020-W-ITF-USA-47A-2020           W100 Charleston SC
# 186064            2020-W-ITF-USA-48A-2020               W25 Orlando FL
# 186072            2020-W-ITF-USA-48A-2020               W25 Orlando FL
#
#        surface  draw_size tourney_level  tourney_date  match_num  winner_id  \
# ...

# %%
tennis.drop_duplicates()
# Out:
#                      tourney_id    tourney_name surface  draw_size  \
# 0                     2019-M020        Brisbane    Hard         32
# 1                     2019-M020        Brisbane    Hard         32
# 2                     2019-M020        Brisbane    Hard         32
# 3                     2019-M020        Brisbane    Hard         32
# 4                     2019-M020        Brisbane    Hard         32
# ...                         ...             ...     ...        ...
# 186068  2020-W-ITF-USA-48A-2020  W25 Orlando FL    Hard         32
# 186069  2020-W-ITF-USA-48A-2020  W25 Orlando FL    Hard         32
# 186070  2020-W-ITF-USA-48A-2020  W25 Orlando FL    Hard         32
# 186071  2020-W-ITF-USA-48A-2020  W25 Orlando FL    Hard         32
# 186072  2020-W-ITF-USA-48A-2020  W25 Orlando FL    Hard         32
#
#        tourney_level  tourney_date  match_num  winner_id winner_entry  \
# 0                  A      20181231        300     105453          NaN
# ...

# %%
def f(x):
    if not x.is_integer() and x != np.nan:
        return x
    
tennis.minutes.apply(lambda x: f(x))

# %%
# Out:
# True

# %%
tennis.isna().sum()
# Out:
# tourney_id                 0
# tourney_name               0
# surface                  162
# draw_size                  0
# tourney_level              0
# tourney_date               0
# match_num                  0
# winner_id                  0
# winner_entry          160251
# winner_name                0
# winner_hand               16
# winner_ht             136745
# winner_ioc                 0
# winner_age              2828
# loser_id                   0
# loser_entry           141927
# loser_name                 0
# loser_hand                71
# loser_ht              147729
# loser_ioc                  0
# loser_age               6502
# score                    175
# best_of                    0
# round                      0
# minutes               104437
# w_ace                 103789
# w_df                  103789
# w_svpt                103789
# w_1stIn               103789
# w_1stWon              103789
# w_2ndWon              103789
# w_SvGms               103785
# ...

# %%
tennis[tennis.winner_id == 210754].head(50)
# Out:
#                       tourney_id       tourney_name surface  draw_size  \
# 12835   2017-W-WITF-AUS-10A-2017      Brisbane $25K    Hard         32
# 17973   2017-W-WITF-GBR-09A-2017   Manchester $100K   Grass         32
# 18300   2017-W-WITF-GER-02A-2017  Altenkirchen $25K  Carpet         32
# 18310   2017-W-WITF-GER-02A-2017  Altenkirchen $25K  Carpet         32
# 18635   2017-W-WITF-GER-13A-2017       Leipzig $25K    Clay         32
# 18666   2017-W-WITF-GER-14A-2017  Braunschweig $25K    Clay         32
# 21362   2017-W-WITF-KAZ-05A-2017       Astana $100K    Hard         32
# 21374   2017-W-WITF-KAZ-05A-2017       Astana $100K    Hard         32
# 21380   2017-W-WITF-KAZ-05A-2017       Astana $100K    Hard         32
# 24126   2017-W-WITF-SWE-02A-2017         Ystad $25K    Clay         32
# 24135   2017-W-WITF-SWE-02A-2017         Ystad $25K    Clay         32
# 24145   2017-W-WITF-SWE-03A-2017          Lund $25K    Clay         32
# ...

# %%
tennis.info()

# %%
tennis.surface.value_counts()

# %%
tennis.winner_ht

# %%
set(tennis.surface)

# %%
set(tennis.loser_entry)

# %%
tennis.tourney_id + tennis.tourney_name
# Out:
# 0                             2019-M020Brisbane
# 1                             2019-M020Brisbane
# 2                             2019-M020Brisbane
# 3                             2019-M020Brisbane
# 4                             2019-M020Brisbane
#                           ...
# 186068    2020-W-ITF-USA-48A-2020W25 Orlando FL
# 186069    2020-W-ITF-USA-48A-2020W25 Orlando FL
# 186070    2020-W-ITF-USA-48A-2020W25 Orlando FL
# 186071    2020-W-ITF-USA-48A-2020W25 Orlando FL
# 186072    2020-W-ITF-USA-48A-2020W25 Orlando FL
# Length: 186073, dtype: object

# %%
tennis[['tourney_id', 'tourney_name', 'tourney_date', 'surface', 'draw_size', 'tourney_level', 'tourney_spectators', 'tourney_revenue']].drop_duplicates()
# Out:
#                      tourney_id        tourney_name  tourney_date surface  \
# 0                     2019-M020            Brisbane      20181231    Hard
# 27                    2019-M020            Brisbane      20181231    Hard
# 96                    2019-0451                Doha      20181231    Hard
# 139                   2019-0891                Pune      20181231    Hard
# 178                   2019-0301            Auckland      20190107    Hard
# ...                         ...                 ...           ...     ...
# 185798  2020-W-ITF-USA-08A-2020    W25 Las Vegas NV      20200302    Hard
# 185853  2020-W-ITF-USA-40A-2020        W80 Macon GA      20201019    Hard
# 185908  2020-W-ITF-USA-42A-2020        W80 Tyler TX      20201026    Hard
# 185963  2020-W-ITF-USA-47A-2020  W100 Charleston SC      20201102    Clay
# 186018  2020-W-ITF-USA-48A-2020      W25 Orlando FL      20201109    Hard
#
#         draw_size tourney_level  tourney_spectators  tourney_revenue
# ...

# %%
tennis[['tourney_id', 'match_num', 'tourney_date', 'winner_name', 'loser_name']].drop_duplicates()
# Out:
#                      tourney_id  match_num  tourney_date  \
# 0                     2019-M020        300      20181231
# 1                     2019-M020        299      20181231
# 2                     2019-M020        298      20181231
# 3                     2019-M020        297      20181231
# 4                     2019-M020        296      20181231
# ...                         ...        ...           ...
# 186068  2020-W-ITF-USA-48A-2020        204      20201109
# 186069  2020-W-ITF-USA-48A-2020        205      20201109
# 186070  2020-W-ITF-USA-48A-2020        206      20201109
# 186071  2020-W-ITF-USA-48A-2020        207      20201109
# 186072  2020-W-ITF-USA-48A-2020        208      20201109
#
#                  winner_name           loser_name
# 0              Kei Nishikori      Daniil Medvedev
# 1            Daniil Medvedev   Jo-Wilfried Tsonga
# 2              Kei Nishikori        Jeremy Chardy
# 3         Jo-Wilfried Tsonga       Alex De Minaur
# ...

# %%
tennis[['tourney_id', 'tourney_date', 'tourney_level']].drop_duplicates()
# Out:
#                      tourney_id  tourney_date tourney_level
# 0                     2019-M020      20181231             A
# 27                    2019-M020      20181231             P
# 96                    2019-0451      20181231             A
# 139                   2019-0891      20181231             A
# 178                   2019-0301      20190107             A
# ...                         ...           ...           ...
# 185798  2020-W-ITF-USA-08A-2020      20200302            25
# 185853  2020-W-ITF-USA-40A-2020      20201019            80
# 185908  2020-W-ITF-USA-42A-2020      20201026            80
# 185963  2020-W-ITF-USA-47A-2020      20201102           100
# 186018  2020-W-ITF-USA-48A-2020      20201109            25
#
# [4911 rows x 3 columns]

# %%
tennis[['tourney_id', 'tourney_name', 'tourney_date', 'surface', 'draw_size', 'tourney_level', 'tourney_spectators', 'tourney_revenue']]
# Out:
# 8

# %%
tennis[tennis.winner_id == 144773]
# Out:
#        tourney_id        tourney_name surface  draw_size tourney_level  \
# 76305   2017-0252         Medellin CH    Clay         32             C
# 76312   2017-0252         Medellin CH    Clay         32             C
# 80440   2017-5016    Floridablanca CH    Clay         32             C
# 80450   2017-5016    Floridablanca CH    Clay         32             C
# 111617  2018-6284      Guadalajara CH    Hard         32             C
# 115781  2018-7911  Puerto Vallarta CH    Hard         32             C
#
#         tourney_date  match_num  winner_id winner_entry    winner_name  \
# 76305       20170710        244     144773          NaN  Jose Olivares
# 76312       20170710        251     144773          NaN  Jose Olivares
# 80440       20170807        239     144773          NaN  Jose Olivares
# 80450       20170807        249     144773          NaN  Jose Olivares
# 111617      20180416        237     144773           WC  Jose Olivares
# ...

# %%
tennis.w_ace
# Out:
# 0          3.0
# 1         10.0
# 2          2.0
# 3         12.0
# 4         12.0
#           ...
# 186068     NaN
# 186069     NaN
# 186070     NaN
# 186071     NaN
# 186072     NaN
# Name: w_ace, Length: 186073, dtype: float64

# %%
set(tennis.tourney_level)
# Out:
# {'10',
#  '100',
#  100,
#  15,
#  '15',
#  25,
#  '25',
#  '50',
#  60,
#  '60',
#  '75',
#  80,
#  '80',
#  'A',
#  'C',
#  'D',
#  'F',
#  'G',
#  'I',
#  'M',
#  'O',
#  'P',
#  'PM',
#  'W'}

# %%
female
# Out:
#            name     surname
# 0         Bobby       Riggs
# 1             X           X
# 2       Martina      Hingis
# 3       Mirjana       Lucic
# 4       Justine       Henin
# ...         ...         ...
# 46167  Kathleen       Allen
# 46168       Mrs  Dransfield
# 46169    Jessie      Greene
# 46170      Mary    Trumbull
# 46171      Inga    Sperling
#
# [46172 rows x 2 columns]

# %%
tennis[tennis.winner_name == 'X X']
# Out:
# Empty DataFrame
# Columns: [tourney_id, tourney_name, surface, draw_size, tourney_level, tourney_date, match_num, winner_id, winner_entry, winner_name, winner_hand, winner_ht, winner_ioc, winner_age, loser_id, loser_entry, loser_name, loser_hand, loser_ht, loser_ioc, loser_age, score, best_of, round, minutes, w_ace, w_df, w_svpt, w_1stIn, w_1stWon, w_2ndWon, w_SvGms, w_bpSaved, w_bpFaced, l_ace, l_df, l_svpt, l_1stIn, l_1stWon, l_2ndWon, l_SvGms, l_bpSaved, l_bpFaced, winner_rank, winner_rank_points, loser_rank, loser_rank_points, tourney_spectators, tourney_revenue]
# Index: []

# %%
tennis[tennis.surface.isna()][['tourney_name', 'surface']]
# Out:
#                        tourney_name surface
# 86167     Fed Cup G2 RR: ECU vs CUB     NaN
# 86168     Fed Cup G2 RR: ECU vs CUB     NaN
# 86169     Fed Cup G2 RR: ECU vs URU     NaN
# 86170     Fed Cup G2 RR: ECU vs URU     NaN
# 86171     Fed Cup G2 RR: URU vs CUB     NaN
# ...                             ...     ...
# 162962  Davis Cup G2 R1: VIE vs HKG     NaN
# 162995  Davis Cup G1 R1: TPE vs CHN     NaN
# 162996  Davis Cup G1 R1: TPE vs CHN     NaN
# 162997  Davis Cup G1 R1: TPE vs CHN     NaN
# 162998  Davis Cup G1 R1: TPE vs CHN     NaN
#
# [162 rows x 2 columns]

# %%
tennis.tourney_date.value_counts()
# Out:
# 20190826    1440
# 20190715    1224
# 20190916    1191
# 20190909    1185
# 20191021    1182
#             ...
# 20180620       4
# 20170217       4
# 20181123       3
# 20181110       3
# 20191124       2
# Name: tourney_date, Length: 375, dtype: int64
